# %% [markdown]
# <a href="https://colab.research.google.com/github/wen27/python_calssification/blob/main/classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 3
print(a)
# Out:
# 3

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris['data'], columns=iris['feature_names'])
df['target'] = iris['target']
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
#train_test_split([1, 2, 3, 4], test_size=0.72 )
#丟到模型前: pandas 
#丟到模型時: numpy

#進sklearn轉為np.array
x = np.array(df.drop('target', axis=1))
y = np.array(df['target'])
#訓練資料0.9 /測試資料0.1 ,x=題目　ｙ＝答案
x_train, x_test, y_train ,y_test = train_test_split(x, y, test_size=0.1)

# %%
#決策樹
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=[14, 14])
plot_tree(clf ,feature_names=iris['feature_names'], filled=True, class_names=iris['target_names'])
# Out:
# [Text(0.5, 0.9166666666666666, 'petal width (cm) <= 0.8\ngini = 0.667\nsamples = 135\nvalue = [46, 45, 44]\nclass = setosa'),
#  Text(0.4, 0.75, 'gini = 0.0\nsamples = 46\nvalue = [46, 0, 0]\nclass = setosa'),
#  Text(0.6, 0.75, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 89\nvalue = [0, 45, 44]\nclass = versicolor'),
#  Text(0.4, 0.5833333333333334, 'petal length (cm) <= 5.05\ngini = 0.153\nsamples = 48\nvalue = [0, 44, 4]\nclass = versicolor'),
#  Text(0.3, 0.4166666666666667, 'sepal length (cm) <= 4.95\ngini = 0.043\nsamples = 45\nvalue = [0, 44, 1]\nclass = versicolor'),
#  Text(0.2, 0.25, 'sepal width (cm) <= 2.45\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.1, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.3, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 43\nvalue = [0, 43, 0]\nclass = versicolor'),
# ...

# %% [markdown]
# # 新增區段
